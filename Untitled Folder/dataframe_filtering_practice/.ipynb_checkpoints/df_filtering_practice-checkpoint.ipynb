# %% [markdown]
# # DataFrame Filtering & Visualization

# %% [markdown]
# ## Instructions
#
# The dataset you will be working with includes intentional homicide and other crime rates in almost every country in the world over the past several years. The data was gathered and compiled by the United Nations. Rates of crimes in each country have been standardized to show the rate per capita per 100,000 people.
#
# Your task is to load the csv file into a dataframe, then filter the data so it only includes 5 countries of your choice.
#
# Filter the dataframe further to represent only one year and one crime.
#
# Once your dataframe is filtered, use this information to create a bargraph similar to the one shown below:

# %% [markdown]
# ![example_graph.png](attachment:example_graph.png)

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("SYB65_328_202209_Intentional homicides and other crimes.csv")

# %%
df
# Out:
#                       T13 Intentional homicides and other crimes Unnamed: 2  \
# 0     Region/Country/Area                                    NaN       Year
# 1                       1          Total, all countries or areas       2005
# 2                       1          Total, all countries or areas       2005
# 3                       1          Total, all countries or areas       2005
# 4                       1          Total, all countries or areas       2010
# ...                   ...                                    ...        ...
# 4861                  716                               Zimbabwe       2008
# 4862                  716                               Zimbabwe       2008
# 4863                  716                               Zimbabwe       2008
# 4864                  716                               Zimbabwe       2010
# 4865                  716                               Zimbabwe       2012
#
# ...
