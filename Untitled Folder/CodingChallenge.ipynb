# %%
import pandas as pd

# %%
df = pd.read_csv("FDA_new_drugs_dec_2022.csv")

# %%
df.head()
# Out:
#    Labeler Code  Product Code  Package Size        NDC  \
# 0           245           871            89  245087189
# 1           310           900            60  310090060
# 2           378           896            55  378089655
# 3           574           167            12  574016712
# 4           781          1831             1  781183101
#
#                                  FDA Product Name  \
# 0  VOGELXO TESTOSTERONE 50MG PKG( (INNER PACKAGE)
# 1           DUAKLIR PRESS IHP 400/12MCG/D 1X60 US
# 2                        Penciclovir Cream 1% 5gm
# 3      Diclofenac Sodium Topical Solution 2% 112g
# 4                AMOX CLAV POT 500/125MG 100TB BT
#
#    Covered Outpatient Drug (COD) Status  \
# 0                                     3
# 1                                     3
# 2                                     4
# 3                                     4
# 4                                     1
#
#   FDA Application Number/OTC Monograph Number Drug Category  Drug Type  \
# ...

# %%
df.iloc[0:3, 1:3]
# Out:
#    Product Code  Package Size
# 0           871            89
# 1           900            60
# 2           896            55

# %%
df.iloc[:, :-1]
# Out:
#      Labeler Code  Product Code  Package Size          NDC  \
# 0             245           871            89    245087189
# 1             310           900            60    310090060
# 2             378           896            55    378089655
# 3             574           167            12    574016712
# 4             781          1831             1    781183101
# ..            ...           ...           ...          ...
# 151         82429           203             1  82429020301
# 152         82429           301            21  82429030121
# 153         82429           308            15  82429030815
# 154         82429           308            24  82429030824
# 155         82429           308            25  82429030825
#
#                                      FDA Product Name  \
# 0      VOGELXO TESTOSTERONE 50MG PKG( (INNER PACKAGE)
# 1               DUAKLIR PRESS IHP 400/12MCG/D 1X60 US
# 2                            Penciclovir Cream 1% 5gm
# ...

# %%
df.iloc[1:,]
# Out:
#      Labeler Code  Product Code  Package Size          NDC  \
# 1             310           900            60    310090060
# 2             378           896            55    378089655
# 3             574           167            12    574016712
# 4             781          1831             1    781183101
# 5             781          1852             1    781185201
# ..            ...           ...           ...          ...
# 151         82429           203             1  82429020301
# 152         82429           301            21  82429030121
# 153         82429           308            15  82429030815
# 154         82429           308            24  82429030824
# 155         82429           308            25  82429030825
#
#                                      FDA Product Name  \
# 1               DUAKLIR PRESS IHP 400/12MCG/D 1X60 US
# 2                            Penciclovir Cream 1% 5gm
# 3          Diclofenac Sodium Topical Solution 2% 112g
# ...

# %%
df.sort_values(by="Product Code", inplace=True)

# %%
df.head()
# Out:
#               Labeler Code  Package Size          NDC  \
# Product Code
# 3                    65250             1  65250000301
# 12                   82429             0  82429001200
# 12                   82429             1  82429001201
# 19                   71288            10  71288001910
# 19                   71288            11  71288001911
#
#                                                FDA Product Name  \
# Product Code
# 3                                       ZILRETTA Single-Use Kit
# 12             ADAPALENE AND BENZOYL PEROXIDE 0.1%/2.5% GEL PAD
# 12             ADAPALENE AND BENZOYL PEROXIDE 0.1%/2.5% GEL PAD
# 19            Tigecycline for Injection, USP 50mg 10mL - Inn...
# 19                     Tigecycline for Injection, USP 50mg 10mL
#
#               Covered Outpatient Drug (COD) Status  \
# Product Code
# 3                                                3
# 12                                              12
# ...

# %%
df.set_index("Product Code", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/qc/fjp6343x1m9dps785q5681tw0000gn/T/ipykernel_96137/3423742655.py in <module>
# ----> 1 df.set_index("Product Code", inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['Product Code'] are in the columns"

# %%
df.iloc[50:100, 1:4]
# Out:
#               Package Size          NDC  \
# Product Code
# 299                     11  50268029911
# 301                     21  82429030121
# 308                     28  69784030828
# 308                     24  82429030824
# 308                     15  82429030815
# 308                     25  82429030825
# 310                      9  60687031009
# 310                     11  60687031011
# 322                      1  60687032201
# 322                     11  60687032211
# 324                     37  69230032437
# 324                     35  69230032435
# 324                     31  69230032431
# 325                      2  50419032502
# 333                     24  63868033324
# 346                     90  52817034690
# 405                     62  46122040562
# 406                     62  46122040662
# 409                     62  46122040962
# 410                     62  46122041062
# 411                     62  46122041162
# 412                     62  46122041262
# ...

# %%
df.loc[202:301, "Labeler Code":"Drug Category"]
# Out:
#               Labeler Code  Package Size          NDC  \
# Product Code
# 202                  82429            16  82429020216
# 203                  82429             1  82429020301
# 203                  31722            20  31722020320
# 234                  46122            34  46122023434
# 235                  46122            26  46122023526
# 261                  70748            30  70748026130
# 261                  70748            60  70748026160
# 262                  60687            42  60687026242
# 262                  60687            48  60687026248
# 299                  50268            15  50268029915
# 299                  50268            11  50268029911
# 301                  82429            21  82429030121
#
#                                                FDA Product Name  \
# Product Code
# 202                                POVIDONE-IODINE SOLUTION 10%
# 203                                               NUMB CREAM 5%
# ...

# %%
df.loc[4:5, 1:7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qc/fjp6343x1m9dps785q5681tw0000gn/T/ipykernel_96137/353211999.py in <module>
# ----> 1 df.loc[4:5, 1:7]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1147             return self._multi_take(tup)
#    1148
# -> 1149         return self._getitem_tuple_same_dim(tup)
#    1150
#    1151     def _get_label(self, label, axis: int):
#
# ...
