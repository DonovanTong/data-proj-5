# %% [markdown]
# ### 1.
# Data visualization needs to be smart, or intellectually relevant to increase credibility. It also must be easy to understand. Lastly, it needs to be coherent. There shouldn't be any unnecessary patterns, colors, or text that is distracting and/or inconsistent.
#
# ### 2.
# - Order: a cultural norm by which we read information. E.g. left to right.
#
# - Hierarchy: Certain aspects of an image stand out more. Light over dark, and red over grey are good examples.
#
# - Clarity: Our brains expect simplicity. In order to help our audience understand, we need to keep our visualizations simple and clean.
#
# - Relationships: Stories are best demonstrated through emphasizing relevant data interactions.
#
# - Convention: A cultural standard that is determined as "right" or "proper".
#
# - These are some key principles that will help to become a more credible, communicative, and trusted data analyst.
#
# ### 3.
# Given the scenarios below, write which graph would be best to use for the data and what makes it an effective choice:
# - Comparison between values: Histogram
#
# - Comparison to the whole: Stacked Column
#
# - Change over time: Column
#
# - Ranking data: Bar graph
#
# - Correlation: Scatterplot
#
# - Geographical charts: Colored map
#
# - Measuring a target: Simple gauge
#
# - Showing Outliers: Box plot
#
#
# Knowing when to use the right visualization is key in communicating the right story or emotion.
#
# ### 4.
#
# - Statistics is a tool that may be used to tell the truth only if one is precise and remains accurate to data. Otherwise, the whole truth is not told.
#
# - One of my favorite misleading graphs I found was georgia's reported cases of covid 19. At first glance it seems as if the cases are decreasing rapidly in every county, but if you look closer, the x axis is set up in descending order of covid cases, not dates. We would see a much more accurate graph if the dates were in the correct order.
#
# - Another one of many were sourced from Fox news. The graph shows gas prices by time period, but the time periods are disproportionate. The graph starts at "last year", then the halfway mark reads "last week", until finally, "Current." The change in price was insignificant.
#
# - Another from Fox news is a pie chart with three parts with percentages reading, "60%", "70%", and "63%" making up a total of 193%. I'm not sure if this could be made more accurate because at the bottom it just says "Source: Opinions."
#
# ### 5.
#
# - Visualization clutter exists when certain conventions are not taken into consideration when creating a graph. Certain colors can inherently indicate certain states of the data such as good or bad.
#
# - A graph includes these main elements: lines, labels, titles, and axis names.
#
# - Less is more. Don't ignore convention. Accuracy and truthfulness are top priorities.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("salary_numeric.csv")

# %%
df
# Out:
#        age  gender  education    industry  industry_experience        salary
# 0       19    Male         12    business                    0   33640.60752
# 1       21    Male         12    business                    2   43554.24216
# 2       19    Male         12    business                    0   39795.29424
# 3       22    Male         12    business                    1   51102.98856
# 4       21    Male         12    business                    1   32809.57056
# ...    ...     ...        ...         ...                  ...           ...
# 25434   66  Female         18  healthcare                   22  113001.50400
# 25435   61  Female         18  healthcare                   22  122528.73600
# 25436   65  Female         18  healthcare                   33  101398.17600
# 25437   61  Female         18  healthcare                   21   93051.55200
# 25438   63  Female         18  healthcare                   20   90307.00800
#
# [25439 rows x 6 columns]

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="industry_experience", y="salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary in USD")
plt.title("Manager Salaries by Years Experience", fontname="DejaVu Sans", fontweight="bold", fontdict={'fontsize':15, })
# Out:
# Text(0.5, 1.0, 'Manager Salaries by Years Experience')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="age", y="salary")
plt.xlabel("Age")
plt.ylabel("Salary in USD")
plt.title("Manager Salaries by Age", fontweight="bold", fontdict={'fontsize':15, })
# Out:
# Text(0.5, 1.0, 'Manager Salaries by Age')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="age", y="industry_experience")
plt.xlabel("Age")
plt.ylabel("Experience")
plt.title("Age by Years Experience", fontname="DejaVu Sans", fontweight="bold", fontdict={'fontsize':15, })
# Out:
# Text(0.5, 1.0, 'Age by Years Experience')

# %%
industrys = df[df["industry"].isin(["technology"])]

# %%
industrys
# Out:
#        age  gender  education    industry  industry_experience        salary
# 412     19    Male         12  technology                    0   38689.08660
# 413     20    Male         12  technology                    0   35900.29980
# 414     20    Male         12  technology                    1   59243.59665
# 415     21    Male         12  technology                    2   34914.20355
# 416     19    Male         12  technology                    2   47640.70845
# ...    ...     ...        ...         ...                  ...           ...
# 23246   61  Female         18  technology                   28  108697.30080
# 23247   61  Female         18  technology                   21  146121.46560
# 23248   61  Female         18  technology                   33  146177.32800
# 23249   67  Female         18  technology                   24  144553.67520
# 23250   61  Female         18  technology                   26  128210.28000
#
# [6382 rows x 6 columns]

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=df, x="industry", y="salary", palette="YlGnBu_r")
# Out:
# <AxesSubplot:xlabel='industry', ylabel='salary'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df, x="industry", palette="YlGnBu_r")
# Out:
# <AxesSubplot:xlabel='industry', ylabel='Count'>

# %%
tech=df[df["industry"].isin(["technology"])]

# %%
tech
# Out:
#        age  gender  education    industry  industry_experience        salary
# 412     19    Male         12  technology                    0   38689.08660
# 413     20    Male         12  technology                    0   35900.29980
# 414     20    Male         12  technology                    1   59243.59665
# 415     21    Male         12  technology                    2   34914.20355
# 416     19    Male         12  technology                    2   47640.70845
# ...    ...     ...        ...         ...                  ...           ...
# 23246   61  Female         18  technology                   28  108697.30080
# 23247   61  Female         18  technology                   21  146121.46560
# 23248   61  Female         18  technology                   33  146177.32800
# 23249   67  Female         18  technology                   24  144553.67520
# 23250   61  Female         18  technology                   26  128210.28000
#
# [6382 rows x 6 columns]

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=tech, y="salary", x="age")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Manager Salaries by Age", fontname="DejaVu Sans", fontweight="bold", fontdict={'fontsize':15, })
# Out:
# Text(0.5, 1.0, 'Manager Salaries by Age')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=tech, x="age", y="salary")
# Out:
# <AxesSubplot:xlabel='age', ylabel='salary'>

# %%
tech2=df[df["industry"].isin(["healthcare"])]

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=df, x="age", y="salary", line_kws={}, scatter_kws={"color":"#86c5dc"})
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Manager Salaries by Age", fontname="DejaVu Sans", fontweight="bold", fontdict={'fontsize':15, })
plt.yticks(np.arange(20000, 190000, step=10000))
# Out:
# ([<matplotlib.axis.YTick at 0x7f88c93d5670>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=df, x="industry_experience", y="salary", line_kws={}, scatter_kws={"color":"#86c5dc"})
plt.xlabel("Experience in Years")
plt.ylabel("Salary")
plt.title("Manager Salaries by Experience", fontname="DejaVu Sans", fontweight="bold", fontdict={'fontsize':15, })
# Out:
# Text(0.5, 1.0, 'Manager Salaries by Experience')

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df, x="salary", palette="YlGnBu_r")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>
